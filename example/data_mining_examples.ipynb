# %% [markdown]
# ## Import

# %%
import sys
sys.path.append('../src')

# %%
from data_mining_essentials import *

# %% [markdown]
# ## Create blobs (data)

# %%
X,y = create_blobs()
# Out:
# There are 1000 samples in the dataset, each having 12 features

# %% [markdown]
# ## Dimensionally reduce blobs
# - PCA and TSNE

# %%
# the source code uses both PCA and TSNE to examplify this
X_pca, X_tsne = dimensional_reduce_blobs(X)
# Out:
# PCA dimensionally reduced our dataset from 12 dimensions to 2. As a result it kept 95.0% of the original variance.

# %% [markdown]
# ## Cluster our 2-dimensional data
# - Elbow method to find optimal k-means clusters
# - DBSCAN and K-means comparisons

# %%
clustering(X_pca)
# Out:
# Enter nclusters at inflection point from elbow method:  3

# %% [markdown]
# ## Silhouette (K-means) Plot
# - Silhouette coefficient measures goodness of clustering

# %%
kmeans_silhoutte(X_tsne)
